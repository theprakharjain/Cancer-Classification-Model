# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\iprak\Desktop\Py-DS-ML-Bootcamp-master\Refactored_Py_DS_ML_Bootcamp-master\TensorFlow_FILES\DATA\cancer_classification.csv")

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
sns.countplot(x = "benign_0__mal_1", data = df)

# %%
df.corr()["benign_0__mal_1"][:-1].sort_values(ascending = False).plot(kind = "bar")

# %%
plt.figure(figsize = (12,9))
sns.heatmap(df.corr())

# %%
X = df.drop("benign_0__mal_1", axis = 1).values
y = df["benign_0__mal_1"].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.layers import Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()

model.add(Dense(30, activation = "relu"))
model.add(Dense(15, activation = "relu"))

# For Binary Classification Problem the last activation is sigmoid 
model.add(Dense(1, activation = "sigmoid"))

model.compile(loss = "binary_crossentropy", optimizer = "adam")

# %%
model.fit(x = X_train, y = y_train, epochs = 600, validation_data = (X_test, y_test))
# Out:
# Train on 426 samples, validate on 143 samples
# Epoch 1/600
# 426/426 [==============================] - 1s 1ms/sample - loss: 0.6766 - val_loss: 0.6687
# Epoch 2/600
# 426/426 [==============================] - 0s 110us/sample - loss: 0.6406 - val_loss: 0.6377
# Epoch 3/600
# 426/426 [==============================] - 0s 104us/sample - loss: 0.6052 - val_loss: 0.5974
# Epoch 4/600
# 426/426 [==============================] - 0s 105us/sample - loss: 0.5663 - val_loss: 0.5535
# Epoch 5/600
# 426/426 [==============================] - 0s 117us/sample - loss: 0.5211 - val_loss: 0.5025
# Epoch 6/600
# 426/426 [==============================] - 0s 154us/sample - loss: 0.4742 - val_loss: 0.4526
# Epoch 7/600
# 426/426 [==============================] - 0s 80us/sample - loss: 0.4263 - val_loss: 0.4047
# Epoch 8/600
# 426/426 [==============================] - 0s 143us/sample - loss: 0.3837 - val_loss: 0.3600
# Epoch 9/600
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
model = Sequential()

model.add(Dense(30, activation = "relu"))
model.add(Dense(15, activation = "relu"))

# For Binary Classification Problem the last activation is sigmoid 
model.add(Dense(1, activation = "sigmoid"))

model.compile(loss = "binary_crossentropy", optimizer = "adam")

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# help(EarlyStopping)

# %%
early_stop = EarlyStopping(monitor = "val_loss", mode = 'min', verbose = 1, patience = 25)

# %%
model.fit(x = X_train, y = y_train, epochs = 600, validation_data = (X_test, y_test),
         callbacks = [early_stop])
# Out:
# Train on 426 samples, validate on 143 samples
# Epoch 1/600
# 426/426 [==============================] - 1s 1ms/sample - loss: 0.6973 - val_loss: 0.6788
# Epoch 2/600
# 426/426 [==============================] - 0s 109us/sample - loss: 0.6739 - val_loss: 0.6591
# Epoch 3/600
# 426/426 [==============================] - 0s 119us/sample - loss: 0.6467 - val_loss: 0.6333
# Epoch 4/600
# 426/426 [==============================] - 0s 111us/sample - loss: 0.6193 - val_loss: 0.6024
# Epoch 5/600
# 426/426 [==============================] - 0s 119us/sample - loss: 0.5845 - val_loss: 0.5627
# Epoch 6/600
# 426/426 [==============================] - 0s 121us/sample - loss: 0.5412 - val_loss: 0.5134
# Epoch 7/600
# 426/426 [==============================] - 0s 117us/sample - loss: 0.4894 - val_loss: 0.4583
# Epoch 8/600
# 426/426 [==============================] - 0s 112us/sample - loss: 0.4360 - val_loss: 0.4036
# Epoch 9/600
# ...

# %%
losses_earlystop = pd.DataFrame(model.history.history)

# %%
losses_earlystop.plot()

# %%
model = Sequential()

model.add(Dense(30, activation = "relu"))
model.add(Dropout(rate = 0.5))

model.add(Dense(15, activation = "relu"))
model.add(Dropout(rate = 0.5))

# For Binary Classification Problem the last activation is sigmoid 
model.add(Dense(1, activation = "sigmoid"))

model.compile(loss = "binary_crossentropy", optimizer = "adam")

# %%
model.fit(x = X_train, y = y_train, epochs = 600, validation_data = (X_test, y_test),
         callbacks = [early_stop])
# Out:
# Train on 426 samples, validate on 143 samples
# Epoch 1/600
# 426/426 [==============================] - 1s 1ms/sample - loss: 0.7603 - val_loss: 0.6944
# Epoch 2/600
# 426/426 [==============================] - 0s 104us/sample - loss: 0.7154 - val_loss: 0.6738
# Epoch 3/600
# 426/426 [==============================] - 0s 125us/sample - loss: 0.6786 - val_loss: 0.6533
# Epoch 4/600
# 426/426 [==============================] - 0s 117us/sample - loss: 0.6503 - val_loss: 0.6314
# Epoch 5/600
# 426/426 [==============================] - 0s 127us/sample - loss: 0.6440 - val_loss: 0.6066
# Epoch 6/600
# 426/426 [==============================] - 0s 126us/sample - loss: 0.6154 - val_loss: 0.5783
# Epoch 7/600
# 426/426 [==============================] - 0s 129us/sample - loss: 0.6058 - val_loss: 0.5519
# Epoch 8/600
# 426/426 [==============================] - 0s 122us/sample - loss: 0.5736 - val_loss: 0.5228
# Epoch 9/600
# ...

# %%
losses_eswithdropout = pd.DataFrame(model.history.history)

# %%
losses_eswithdropout.plot()

# %%
predictions = model.predict_classes(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        55
#            1       0.99      0.97      0.98        88
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[54  1]
#  [ 3 85]]
